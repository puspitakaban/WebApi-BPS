# %%
import requests 
import pandas as pd

# %%
r = requests.get(url = "https://webapi.bps.go.id/v1/api/list/model/indicators/domain/1200/key/dc6660972b3db647a0d48eba65fba051/")

# %% [markdown]
# ## List of Available Domain

# %%
URL = "https://webapi.bps.go.id/v1/api/domain/type/all/key/dc6660972b3db647a0d48eba65fba051/"
  
r = requests.get(url = URL) 

data = r.json()

# %%
pd.DataFrame.from_dict(data['data'][1])
# Out:
#     domain_id   domain_name                        domain_url
# 0        0000         Pusat              http://www.bps.go.id
# 1        1100          Aceh            https://aceh.bps.go.id
# 2        1101      Simeulue     https://simeuluekab.bps.go.id
# 3        1102  Aceh Singkil  https://acehsingkilkab.bps.go.id
# 4        1103  Aceh Selatan  https://acehselatankab.bps.go.id
# ..        ...           ...                               ...
# 544      9433        Puncak       https://puncakkab.bps.go.id
# 545      9434       Dogiyai      https://dogiyaikab.bps.go.id
# 546      9435    Intan Jaya    https://intanjayakab.bps.go.id
# 547      9436        Deiyai       https://deiyaikab.bps.go.id
# 548      9471      Jayapura    https://jayapurakota.bps.go.id
#
# [549 rows x 3 columns]

# %% [markdown]
# ## Strategic Indicator

# %%
r = requests.get(url = "https://webapi.bps.go.id/v1/api/list/model/indicators/domain/1200/key/dc6660972b3db647a0d48eba65fba051/")

data = r.json()

# %%
pd.DataFrame.from_dict(data['data'][1])
# Out:
#    indicator_id                                       title  \
# 0             9                 Nilai Ekspor, November 2020
# 1             6                      Inflasi, Desember 2020
# 2             5             Pertumbuhan Ekonomi, Tahun 2019
# 3            10                  Nilai Impor, November 2020
# 4             4    Jumlah Penduduk Miskin, Maret 2019 (000)
# 5            11     Nilai Neraca Perdagangan, November 2020
# 6            12       Jumlah Penduduk, 2019 (Proyeksi 2010)
# 7             3  Tingkat Pengangguran Terbuka, Agustus 2019
# 8            13         Umur Harapan Hidup Saat Lahir, 2020
# 9             2                      Gini Rasio, Maret 2019
#
#                                                 name            data_source  \
# 0         Nilai Ekspor Sumatera Utara, November 2020  Badan Pusat Statistik
# 1              Inflasi Sumatera Utara, Desember 2020  Badan Pusat Statistik
# ...
